# %%
import pandas as pd

# %%
df = pd.read_csv (r"C:\Users\NXF30487\Desktop\aaron\temp\cricketdata.csv")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
#rename multiple columns in a list

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO' : 'Not_Outs', 'HS' : 'Highest_InnsScore', 'BF' : 'Balls_Faced', 'SR' : 'Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50  0   4s  6s
# 0               334  99.94       9800+       58.60   29  13  7  626   6
# 1               186  62.15        1287       91.76    4   7  1  141  23
# 2              269*  61.87        2667       55.68    5   4  2  186   5
# 3               274  60.97       1707+       54.48    7  11  1  246  11
# 4              270*  60.83        416+       56.00   10   5  2  104   1

# %%
#checkfornullvalues

# %%
df.isnull().any()
# Out:
# Player               False
# Span                 False
# Matches              False
# Inns                 False
# Not_Outs             False
# Runs                 False
# Highest_InnsScore    False
# Ave                  False
# Balls_Faced           True
# Strike_Rate           True
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958       48    81         5  4455
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50  0   4s  6s
# 9                207  58.61         NaN         NaN   15  19  6  258   2
# 17               220  56.68         NaN         NaN   15  14  1  107  11

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50   0    4s  6s
# 0                334  99.94       9800+       58.60   29  13   7   626   6
# ...

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_InnsScore, Ave, Balls_Faced, Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df.isnull().any()
# Out:
# Player               False
# Span                 False
# Matches              False
# Inns                 False
# Not_Outs             False
# Runs                 False
# Highest_InnsScore    False
# Ave                  False
# Balls_Faced          False
# Strike_Rate           True
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# dtype: bool

# %%
df[df['Strike_Rate'].isna()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958       48    81         5  4455
# 17  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50  0   4s  6s
# 9                207  58.61           0         NaN   15  19  6  258   2
# 17               220  56.68           0         NaN   15  14  1  107  11

# %%
df['Strike_Rate']= df['Strike_Rate'].fillna(0)
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50   0    4s  6s
# 0                334  99.94       9800+       58.60   29  13   7   626   6
# ...

# %%
df[df['Strike_Rate'].isnull()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_InnsScore, Ave, Balls_Faced, Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df.isnull().any()
# Out:
# Player               False
# Span                 False
# Matches              False
# Inns                 False
# Not_Outs             False
# Runs                 False
# Highest_InnsScore    False
# Ave                  False
# Balls_Faced          False
# Strike_Rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# dtype: bool

# %%
#drop duplicate rows

# %%
df.duplicated().any()
# Out:
# False

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 13   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 54    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50   0   4s  6s
# 5               270*  60.83        416+       56.00   10   5   2  104   1
# 13              365*  57.78       4063+       53.58   26  30  12  593  32
# 16               211  56.94       5363+       46.22   15  28   4  276   8
# 54              254*  49.15       15924       55.56   29  30  14  991  26

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 5   GA Headley (WI)  1930-1954       22    40         4  2190
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 13   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 53    V Kohli (IND)  2011-2024      113   191        11  8848
# 54    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50   0   4s  6s
# 4               270*  60.83        416+       56.00   10   5   2  104   1
# 5               270*  60.83        416+       56.00   10   5   2  104   1
# 12              365*  57.78       4063+       53.58   26  30  12  593  32
# 13              365*  57.78       4063+       53.58   26  30  12  593  32
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 53    V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_InnsScore    Ave Balls_Faced Strike_Rate  100  50   0   4s  6s
# 4               270*  60.83        416+       56.00   10   5   2  104   1
# 12              365*  57.78       4063+       53.58   26  30  12  593  32
# 15               211  56.94       5363+       46.22   15  28   4  276   8
# 53              254*  49.15       15924       55.56   29  30  14  991  26

# %%
# split span into start and end date

# %%
df['Span'].str.split('-', n=1, expand=True)
# Out:
#        0     1
# 0   1928  1948
# 1   2022  2023
# 2   2015  2016
# 3   1963  1970
# 4   1930  1954
# ..   ...   ...
# 61  1965  1981
# 62  2002  2014
# 63  1924  1934
# 64  1930  1938
# 65  1928  1934
#
# [62 rows x 2 columns]

# %%
df[['Rookie_Year','Final_Year']] = df['Span'].str.split('-', n=1, expand=True)
df
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_26264\3451544764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Rookie_Year','Final_Year']] = df['Span'].str.split('-', n=1, expand=True)
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_26264\3451544764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Rookie_Year','Final_Year']] = df['Span'].str.split('-', n=1, expand=True)
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# ...

# %%
#drop span column

# %%
df = df.drop(columns = 'Span')
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_InnsScore    Ave  \
# 0    DG Bradman (AUS)       52    80        10  6996               334  99.94
# 1      HC Brook (ENG)       12    20         1  1181               186  62.15
# 2      AC Voges (AUS)       20    31         7  1485              269*  61.87
# 3     RG Pollock (SA)       23    41         4  2256               274  60.97
# 4     GA Headley (WI)       22    40         4  2190              270*  60.83
# ..                ...      ...   ...       ...   ...               ...    ...
# 61   KD Walters (AUS)       74   125        14  5357               250  48.26
# 62  GC Smith (ICC/SA)      117   205        13  9265               277  48.25
# 63  WH Ponsford (AUS)       29    48         4  2122               266  48.22
# 64    SJ McCabe (AUS)       39    62         5  2748               232  48.21
# 65   DR Jardine (ENG)       22    33         6  1296               127  48.00
#
# ...

# %%
#separate country from players

# %%
df['Player'].str.split('(', n=2, expand=True)
# Out:
#                0        1
# 0    DG Bradman      AUS)
# 1      HC Brook      ENG)
# 2      AC Voges      AUS)
# 3    RG Pollock       SA)
# 4    GA Headley       WI)
# ..           ...      ...
# 61   KD Walters      AUS)
# 62     GC Smith   ICC/SA)
# 63  WH Ponsford      AUS)
# 64    SJ McCabe      AUS)
# 65   DR Jardine      ENG)
#
# [62 rows x 2 columns]

# %%
df[['Players','Country']] = df['Player'].str.split('(', n=2, expand=True)
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_InnsScore    Ave  \
# 0    DG Bradman (AUS)       52    80        10  6996               334  99.94
# 1      HC Brook (ENG)       12    20         1  1181               186  62.15
# 2      AC Voges (AUS)       20    31         7  1485              269*  61.87
# 3     RG Pollock (SA)       23    41         4  2256               274  60.97
# 4     GA Headley (WI)       22    40         4  2190              270*  60.83
# ..                ...      ...   ...       ...   ...               ...    ...
# 61   KD Walters (AUS)       74   125        14  5357               250  48.26
# 62  GC Smith (ICC/SA)      117   205        13  9265               277  48.25
# 63  WH Ponsford (AUS)       29    48         4  2122               266  48.22
# 64    SJ McCabe (AUS)       39    62         5  2748               232  48.21
# 65   DR Jardine (ENG)       22    33         6  1296               127  48.00
#
# ...

# %%
df['Country'] = df['Country'].str.strip(')')

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_InnsScore    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996               334  99.94
# 1    HC Brook (ENG)       12    20         1  1181               186  62.15
# 2    AC Voges (AUS)       20    31         7  1485              269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256               274  60.97
# 4   GA Headley (WI)       22    40         4  2190              270*  60.83
#
#   Balls_Faced Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year  \
# 0       9800+       58.60   29  13  7  626   6        1928       1948
# 1        1287       91.76    4   7  1  141  23        2022       2023
# 2        2667       55.68    5   4  2  186   5        2015       2016
# 3       1707+       54.48    7  11  1  246  11        1963       1970
# 4        416+       56.00   10   5  2  104   1        1930       1954
#
#        Players Country
# 0  DG Bradman      AUS
# 1    HC Brook      ENG
# ...

# %%
df.head()
# Out:
#    Matches  Inns  Not_Outs  Runs Highest_InnsScore    Ave Balls_Faced  \
# 0       52    80        10  6996               334  99.94       9800+
# 1       12    20         1  1181               186  62.15        1287
# 2       20    31         7  1485              269*  61.87        2667
# 3       23    41         4  2256               274  60.97       1707+
# 4       22    40         4  2190              270*  60.83        416+
#
#   Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year      Players Country
# 0       58.60   29  13  7  626   6        1928       1948  DG Bradman      AUS
# 1       91.76    4   7  1  141  23        2022       2023    HC Brook      ENG
# 2       55.68    5   4  2  186   5        2015       2016    AC Voges      AUS
# 3       54.48    7  11  1  246  11        1963       1970  RG Pollock       SA
# 4       56.00   10   5  2  104   1        1930       1954  GA Headley       WI

# %%
desired_order = ['Players','Country','Matches','Inns','Not_Outs','Runs','Highest_InnsScore','Ave','Balls_Faced','Strike_Rate','100','50','0','4s','6s','Rookie_Year','Final_Year']

# %%
df = df[desired_order]

# %%
df
# Out:
#          Players Country  Matches  Inns  Not_Outs  Runs Highest_InnsScore  \
# 0    DG Bradman      AUS       52    80        10  6996               334
# 1      HC Brook      ENG       12    20         1  1181               186
# 2      AC Voges      AUS       20    31         7  1485              269*
# 3    RG Pollock       SA       23    41         4  2256               274
# 4    GA Headley       WI       22    40         4  2190              270*
# ..           ...     ...      ...   ...       ...   ...               ...
# 61   KD Walters      AUS       74   125        14  5357               250
# 62     GC Smith   ICC/SA      117   205        13  9265               277
# 63  WH Ponsford      AUS       29    48         4  2122               266
# 64    SJ McCabe      AUS       39    62         5  2748               232
# 65   DR Jardine      ENG       22    33         6  1296               127
#
#       Ave Balls_Faced Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
#change data types

# %%
df.dtypes
# Out:
# Players               object
# Country               object
# Matches                int64
# Inns                   int64
# Not_Outs               int64
# Runs                   int64
# Highest_InnsScore     object
# Ave                  float64
# Balls_Faced           object
# Strike_Rate           object
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_Year           object
# Final_Year            object
# dtype: object

# %%
df['Highest_InnsScore'].str.replace('*','')
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_InnsScore, Length: 62, dtype: object

# %%
df['Highest_InnsScore'] = df['Highest_InnsScore'].str.replace('*','')
df
# Out:
#          Players Country  Matches  Inns  Not_Outs  Runs Highest_InnsScore  \
# 0    DG Bradman      AUS       52    80        10  6996               334
# 1      HC Brook      ENG       12    20         1  1181               186
# 2      AC Voges      AUS       20    31         7  1485               269
# 3    RG Pollock       SA       23    41         4  2256               274
# 4    GA Headley       WI       22    40         4  2190               270
# ..           ...     ...      ...   ...       ...   ...               ...
# 61   KD Walters      AUS       74   125        14  5357               250
# 62     GC Smith   ICC/SA      117   205        13  9265               277
# 63  WH Ponsford      AUS       29    48         4  2122               266
# 64    SJ McCabe      AUS       39    62         5  2748               232
# 65   DR Jardine      ENG       22    33         6  1296               127
#
#       Ave Balls_Faced Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Highest_InnsScore'] = df['Highest_InnsScore'].astype('int')

# %%
df.dtypes
# Out:
# Players               object
# Country               object
# Matches                int64
# Inns                   int64
# Not_Outs               int64
# Runs                   int64
# Highest_InnsScore      int32
# Ave                  float64
# Balls_Faced           object
# Strike_Rate           object
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_Year           object
# Final_Year            object
# dtype: object

# %%
df = df.astype({'Rookie_Year':'int', 'Final_Year':'int'})

# %%
df['Matches'] = df['Matches'].astype('int')

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.replace('+','')

# %%
df.head()
# Out:
#        Players Country  Matches  Inns  Not_Outs  Runs  Highest_InnsScore  \
# 0  DG Bradman      AUS       52    80        10  6996                334
# 1    HC Brook      ENG       12    20         1  1181                186
# 2    AC Voges      AUS       20    31         7  1485                269
# 3  RG Pollock       SA       23    41         4  2256                274
# 4  GA Headley       WI       22    40         4  2190                270
#
#      Ave Balls_Faced Strike_Rate  100  50  0   4s  6s  Rookie_Year  Final_Year
# 0  99.94        9800       58.60   29  13  7  626   6         1928        1948
# 1  62.15        1287       91.76    4   7  1  141  23         2022        2023
# 2  61.87        2667       55.68    5   4  2  186   5         2015        2016
# 3  60.97        1707       54.48    7  11  1  246  11         1963        1970
# 4  60.83         416       56.00   10   5  2  104   1         1930        1954

# %%
df['Balls_Faced'].isna().any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# Players              False
# Country              False
# Matches              False
# Inns                 False
# Not_Outs             False
# Runs                 False
# Highest_InnsScore    False
# Ave                  False
# Balls_Faced           True
# Strike_Rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# Rookie_Year          False
# Final_Year           False
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#         Players Country  Matches  Inns  Not_Outs  Runs  Highest_InnsScore  \
# 9    ED Weekes       WI       48    81         5  4455                207
# 17  CL Walcott       WI       44    74         7  3798                220
#
#       Ave Balls_Faced Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 9   58.61         NaN           0   15  19  6  258   2         1948
# 17  56.68         NaN           0   15  14  1  107  11         1948
#
#     Final_Year
# 9         1958
# 17        1960

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Players'] = df['Players'].str.strip()

# %%
df[df['Players'].isin(['CL Walcott','ED Weekes'])]
# Out:
#        Players Country  Matches  Inns  Not_Outs  Runs  Highest_InnsScore  \
# 9    ED Weekes      WI       48    81         5  4455                207
# 17  CL Walcott      WI       44    74         7  3798                220
#
#       Ave Balls_Faced Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 9   58.61           0           0   15  19  6  258   2         1948
# 17  56.68           0           0   15  14  1  107  11         1948
#
#     Final_Year
# 9         1958
# 17        1960

# %%
df['Balls_Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df['Balls_Faced'].astype('int')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#              Players  Country  Matches  Inns  Not_Outs   Runs  \
# 0         DG Bradman      AUS       52    80        10   6996
# 1           HC Brook      ENG       12    20         1   1181
# 2           AC Voges      AUS       20    31         7   1485
# 3         RG Pollock       SA       23    41         4   2256
# 4         GA Headley       WI       22    40         4   2190
# 6        H Sutcliffe      ENG       54    84         9   4555
# 7          E Paynter      ENG       20    31         5   1540
# 8      KF Barrington      ENG       82   131        15   6806
# 9          ED Weekes       WI       48    81         5   4455
# 10        WR Hammond      ENG       85   140        16   7249
# 11         SPD Smith      AUS      105   187        23   9514
# 12         GS Sobers       WI       93   160        21   8032
# 14     KC Sangakkara       SL      134   233        17  12400
# 15          JB Hobbs      ENG       61   102         7   5410
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.replace('-','0')
df['Strike_Rate'] = df['Strike_Rate'].str.replace('-','0')
df
# Out:
#              Players  Country  Matches  Inns  Not_Outs   Runs  \
# 0         DG Bradman      AUS       52    80        10   6996
# 1           HC Brook      ENG       12    20         1   1181
# 2           AC Voges      AUS       20    31         7   1485
# 3         RG Pollock       SA       23    41         4   2256
# 4         GA Headley       WI       22    40         4   2190
# 6        H Sutcliffe      ENG       54    84         9   4555
# 7          E Paynter      ENG       20    31         5   1540
# 8      KF Barrington      ENG       82   131        15   6806
# 9          ED Weekes       WI       48    81         5   4455
# 10        WR Hammond      ENG       85   140        16   7249
# 11         SPD Smith      AUS      105   187        23   9514
# 12         GS Sobers       WI       93   160        21   8032
# 14     KC Sangakkara       SL      134   233        17  12400
# 15          JB Hobbs      ENG       61   102         7   5410
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df
# Out:
#              Players  Country  Matches  Inns  Not_Outs   Runs  \
# 0         DG Bradman      AUS       52    80        10   6996
# 1           HC Brook      ENG       12    20         1   1181
# 2           AC Voges      AUS       20    31         7   1485
# 3         RG Pollock       SA       23    41         4   2256
# 4         GA Headley       WI       22    40         4   2190
# 6        H Sutcliffe      ENG       54    84         9   4555
# 7          E Paynter      ENG       20    31         5   1540
# 8      KF Barrington      ENG       82   131        15   6806
# 9          ED Weekes       WI       48    81         5   4455
# 10        WR Hammond      ENG       85   140        16   7249
# 11         SPD Smith      AUS      105   187        23   9514
# 12         GS Sobers       WI       93   160        21   8032
# 14     KC Sangakkara       SL      134   233        17  12400
# 15          JB Hobbs      ENG       61   102         7   5410
# ...

# %%
df['Strike_Rate'] = df['Strike_Rate'].fillna(0)

# %%
df
# Out:
#              Players  Country  Matches  Inns  Not_Outs   Runs  \
# 0         DG Bradman      AUS       52    80        10   6996
# 1           HC Brook      ENG       12    20         1   1181
# 2           AC Voges      AUS       20    31         7   1485
# 3         RG Pollock       SA       23    41         4   2256
# 4         GA Headley       WI       22    40         4   2190
# 6        H Sutcliffe      ENG       54    84         9   4555
# 7          E Paynter      ENG       20    31         5   1540
# 8      KF Barrington      ENG       82   131        15   6806
# 9          ED Weekes       WI       48    81         5   4455
# 10        WR Hammond      ENG       85   140        16   7249
# 11         SPD Smith      AUS      105   187        23   9514
# 12         GS Sobers       WI       93   160        21   8032
# 14     KC Sangakkara       SL      134   233        17  12400
# 15          JB Hobbs      ENG       61   102         7   5410
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['Strike_Rate'] = df['Strike_Rate'].astype('float')

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_26264\1115469300.py in ?()
# ----> 1 df.dtype
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# Players               object
# Country               object
# Matches                int32
# Inns                   int64
# Not_Outs               int64
# Runs                   int64
# Highest_InnsScore      int32
# Ave                  float64
# Balls_Faced            int32
# Strike_Rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_Year            int32
# Final_Year             int32
# dtype: object

# %%
#Create a new career length column

# %%
df['Career_length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#              Players  Country  Matches  Inns  Not_Outs   Runs  \
# 0         DG Bradman      AUS       52    80        10   6996
# 1           HC Brook      ENG       12    20         1   1181
# 2           AC Voges      AUS       20    31         7   1485
# 3         RG Pollock       SA       23    41         4   2256
# 4         GA Headley       WI       22    40         4   2190
# 6        H Sutcliffe      ENG       54    84         9   4555
# 7          E Paynter      ENG       20    31         5   1540
# 8      KF Barrington      ENG       82   131        15   6806
# 9          ED Weekes       WI       48    81         5   4455
# 10        WR Hammond      ENG       85   140        16   7249
# 11         SPD Smith      AUS      105   187        23   9514
# 12         GS Sobers       WI       93   160        21   8032
# 14     KC Sangakkara       SL      134   233        17  12400
# 15          JB Hobbs      ENG       61   102         7   5410
# ...

# %%
#calculations within data frame

# %%
#what is the average career length

# %%
df['Career_length'].mean()
# Out:
# 13.14516129032258

# %%
#average batting striker for players above 10 years career length

# %%
df[df['Career_length']>10]['Strike_Rate'].mean()
# Out:
# 47.95363636363636

# %%
#find players who played before 1960

# %%
df[df['Rookie_Year']<1960]['Players'].count()
# Out:
# 23

# %%
#max highest inns score by country

# %%
df.groupby('Country')['Highest_InnsScore'].max().to_frame('Highest_InnsScore').reset_index().sort_values('Highest_InnsScore',ascending = False)
# Out:
#     Country  Highest_InnsScore
# 5    ICC/WI                400
# 0       AUS                380
# 10       SL                374
# 11       WI                365
# 1       ENG                364
# 3   ICC/PAK                329
# 2   ICC/IND                319
# 8       PAK                313
# 9        SA                278
# 4    ICC/SA                277
# 6       IND                254
# 7        NZ                251
# 12      ZIM                232

# %%
#100s,50s,0s by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.250000   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
