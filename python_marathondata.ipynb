# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\NXF30487\Desktop\aaron\temp\jmp\TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\2948377463.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\NXF30487\Desktop\aaron\temp\jmp\TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up date

# %%
#only want USA races, 50k or 50mils, 2020

# %%
#step 1, only show 50mi or 50k
#50mi
#50km

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine 50km/50mi with isin

# %%
df[df['Event distance/length'].isin(['50mi','50km'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
#split country from Event Name

# %%
df['Event name'].str.split('(', n=1, expand= True)
# Out:
#                                            0     1
# 0                             Selva Costera   CHI)
# 1                             Selva Costera   CHI)
# 2                             Selva Costera   CHI)
# 3                             Selva Costera   CHI)
# 4                             Selva Costera   CHI)
# ...                                      ...   ...
# 7461190                 La SainteLyon 65 km   FRA)
# 7461191                 La SainteLyon 65 km   FRA)
# 7461192  Szombathely 24 hours running Race    HUN)
# 7461193  Szombathely 24 hours running Race    HUN)
# 7461194  Szombathely 24 hours running Race    HUN)
#
# [7461195 rows x 2 columns]

# %%
df[['Event name', 'Country']] = df['Event name'].str.split('(', n=1, expand= True)

# %%
df.head(10)
# Out:
#    Year of event Event dates      Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera                   50km
# 1           2018  06.01.2018  Selva Costera                   50km
# 2           2018  06.01.2018  Selva Costera                   50km
# 3           2018  06.01.2018  Selva Costera                   50km
# 4           2018  06.01.2018  Selva Costera                   50km
# 5           2018  06.01.2018  Selva Costera                   50km
# 6           2018  06.01.2018  Selva Costera                   50km
# 7           2018  06.01.2018  Selva Costera                   50km
# 8           2018  06.01.2018  Selva Costera                   50km
# 9           2018  06.01.2018  Selva Costera                   50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# ...

# %%
df['Country'] = df['Country'].str.strip(')')

# %%
df.head(10)
# Out:
#    Year of event Event dates      Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera                   50km
# 1           2018  06.01.2018  Selva Costera                   50km
# 2           2018  06.01.2018  Selva Costera                   50km
# 3           2018  06.01.2018  Selva Costera                   50km
# 4           2018  06.01.2018  Selva Costera                   50km
# 5           2018  06.01.2018  Selva Costera                   50km
# 6           2018  06.01.2018  Selva Costera                   50km
# 7           2018  06.01.2018  Selva Costera                   50km
# 8           2018  06.01.2018  Selva Costera                   50km
# 9           2018  06.01.2018  Selva Costera                   50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# ...

# %%
df[(df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event'] ==2020) & (df['Country'] == 'USA')]
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2= df[(df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event'] ==2020) & (df['Country'] == 'USA')]
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#validate data only have USA races, 50k or 50mils, 2020

# %%
df2['Event distance/length'].unique()
# Out:
# array(['50km', '50mi'], dtype=object)

# %%
df2['Country'].unique()
# Out:
# array(['USA'], dtype=object)

# %%
df2.shape
# Out:
# (26090, 14)

# %%
#clean up athlete age

# %%
df2['Athlete_Age'] = df2['Athlete age category'].str[-2:]
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\1208170671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_Age'] = df2['Athlete age category'].str[-2:]

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2['Athlete_Age2'] = df2['Year of event'] - df2['Athlete year of birth']
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\2851947204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_Age2'] = df2['Year of event'] - df2['Athlete year of birth']

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
#remove h from athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.strip('h')
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\2857440698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.strip('h')

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20            3:17:55
# 2539946                  50km                         20            4:02:32
# 2539947                  50km                         20            4:07:57
# 2539948                  50km                         20            4:22:02
# 2539949                  50km                         20            4:27:34
#
# ...

# %%
#drop columns Athlete club, Athlete year of birth, Athlete_Age, Athlete age category

# %%
df2 = df2.drop( columns = ['Athlete club', 'Athlete year of birth', 'Athlete_Age', 'Athlete age category'])

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete country                0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Country                        0
# Athlete_Age2                 233
# dtype: int64

# %%
df2[df2['Athlete_Age2'].isna() == 1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2 = df2.dropna()

# %%
#check for duplicates

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete country, Athlete gender, Athlete average speed, Athlete ID, Country, Athlete_Age2]
# Index: []

# %%
#reset index

# %%
df2.reset_index( drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix data types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete country               object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Country                       object
# Athlete_Age                    int32
# dtype: object

# %%
df2['Athlete_Age2'] = df2['Athlete_Age2'].astype(int)
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\219869994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_Age2'] = df2['Athlete_Age2'].astype(int)

# %%
df2['Athlete_Age'] = df2['Athlete_Age2']
# Out:
# C:\Users\NXF30487\AppData\Local\Temp\1\ipykernel_20312\2263771537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_Age'] = df2['Athlete_Age2']

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2.drop (columns = ['Athlete_Age2'])
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2 = df2.drop (columns = ['Athlete_Age2'])

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype('float')

# %%
#rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete country               object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#Country                       object
#Athlete_Age                    int32
#dtype: object

# %%
df2 = df2.rename ( columns = {'Year of event' : 'year', 'Event dates' : 'race_day', 'Event name' : 'race_name', 'Event distance/length' : 'race_length' , 'Event number of finishers' : 'race_number_of_finishers', 'Athlete performance' : 'athlete_performance', 'Athlete country' : 'athlete_country', 'Athlete gender' : 'athlete_gender', 'Athlete average speed' : 'athlete_average_speed', 'Athlete ID' : 'athlete_id', 'Athlete_Age' : 'athlete_age'    })

# %%
#plot charts & graph

# %%
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# athlete_country              object
# athlete_gender               object
# athlete_average_speed       float64
# athlete_id                    int64
# athlete_age                   int32
# dtype: object

# %%
sns.histplot(df2['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df2, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df2[df2['race_length'] == '50mi']['athlete_average_speed'])
# Out:
# C:\Users\NXF30487\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot (df2, x='race_length', y = 'athlete_average_speed', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot (df2, x = 'athlete_age', y = 'athlete_average_speed', hue = 'athlete_gender')
# Out:
# C:\Users\NXF30487\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#questions i want to find out about the data

# %%
#year                          int64
#race_day                     object
#race_name                    object
#race_length                  object
#race_number_of_finishers      int64
#athlete_performance          object
#athlete_country              object
#athlete_gender               object
#athlete_average_speed       float64
#athlete_id                    int64
#athlete_age                   int32
#dtype: object

# %%
#diff in speed for 50mi, 50km male to female

# %%
df2.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.083011
#              M                 7.738985
# 50mi         F                 6.834371
#              M                 7.257633
# Name: athlete_average_speed, dtype: float64

# %%
#what age groups are the best in the 50m race (20 + races min)

# %%
df2.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count>19').head(5)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91

# %%
#seasons for the data - slower in summer than winter?
# spring 3-5
# summer 6-8
# fall 9-11
#winter 12-2

# %%
df2['race_month'] = df2['race_day'].str.split('.').str.get(1).astype(int)

# %%
df2['race_season'] = df2['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')

# %%
df2.groupby('race_season')['athlete_average_speed'].mean().sort_values(ascending = False)
# Out:
# race_season
# Spring    7.684430
# Winter    7.518187
# Fall      7.406619
# Summer    6.869336
# Name: athlete_average_speed, dtype: float64
